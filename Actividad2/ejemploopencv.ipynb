# %% [markdown]
# # Mi primer proyecto de vision computacional
# Este primer proyecto es un ejemplo de como utilizar OpenCV de manera efectiva

# %% [markdown]
# # Importar librerias
# import cv2
# import numpy as np
# from matplotlib import pyplot as plt

# %%
# Importar librerias
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
bgr = cv2.imread('descarga.jpeg')
print("El tamaño de la imagen es: ", bgr.shape)
# convertir BGR a RGB
rgb = cv2.cvtColor(bgr, cv2.COLOR_BGR2RGB)
# Mostrar imagen
plt.imshow(rgb) 
# mostrar la imagen en escala de grises
gray = cv2.cvtColor(bgr, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')
# Mostrar las componentes de color de la imagen
plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(bgr[:,:,0], cmap='gray')
plt.title('Componente Azul')
plt.subplot(1,3,2)
plt.imshow(bgr[:,:,1], cmap='gray')
plt.title('Componente Verde')
plt.subplot(1,3,3)
plt.imshow(bgr[:,:,2], cmap='gray')
plt.title('Componente Roja')
plt.show()
# Out:
# El tamaño de la imagen es:  (250, 202, 3)

# %%
# mostrar las componentes HLS de la imagen
hls = cv2.cvtColor(bgr, cv2.COLOR_BGR2HLS)
plt.figure(figsize=(10,10))
plt.subplot(1,3,1)
plt.imshow(hls[:,:,0], cmap='gray')
plt.title('Componente H')
plt.subplot(1,3,2)
plt.imshow(hls[:,:,1], cmap='gray')
plt.title('Componente L')
plt.subplot(1,3,3)
plt.imshow(hls[:,:,2], cmap='gray')
plt.title('Componente S')
plt.show()

# %%
#aplicar filtro gaussiano
blur = cv2.GaussianBlur(bgr, (15,15), 0)
plt.imshow(cv2.cvtColor(blur, cv2.COLOR_BGR2RGB))
